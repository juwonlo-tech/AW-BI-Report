# %% [markdown]
# ### Title: Adventure Works Cycles BI Report
# ### Author: Juwonlo Siyanbade
# ### Date: Oct 26, 2021

# %% [markdown]
# This notebook contains screenshots of the business intelligence solution designed from scratch for Adventure Works, a global manufacturing company.

# %% [markdown]
# #### Brief:
# The company needs a way to track KPIs (sales, revenue, profit, returns), compare
# regional performance, analyze product-level trends and forecasts, and identify high-value customers.
#
# All I was given is a folder of raw csv files, containing information about transactions, returns, products, customers and territories.

# %% [markdown]
# The model used to connect the data:

# %% [markdown]
# ![AW-Report-Model.png](attachment:AW-Report-Model.png)

# %% [markdown]
# The report generated:

# %% [markdown]
# ![AW-Report1.png](attachment:AW-Report1.png)

# %% [markdown]
# ![AW-Report2.png](attachment:AW-Report2.png)

# %% [markdown]
# ![AW-Report3.png](attachment:AW-Report3.png)
